# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, TimestampType

schema = StructType([StructField("raceId", IntegerType(), False),
                    StructField("year", IntegerType(), False),
                    StructField("round", IntegerType(), False),
                    StructField("circuitId", IntegerType(), False),
                    StructField("name", StringType(), False),
                    StructField("date", DateType(), False),
                    StructField("time", TimestampType(), True),
                    StructField("url", StringType(), True)])
# Out:
# StatementMeta(, 95ce693a-80fc-4232-bb23-f26d0cd3b01b, 3, Finished, Available, Finished)

# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder.getOrCreate()

# Path to the folder containing all CSV files
csv_folder_path = "abfss://Formula1@onelake.dfs.fabric.microsoft.com/Formula1_lakehouse.Lakehouse/Files/raw/races/races.csv"

# Load all CSV files in the folder without headers
df = spark.read.csv(csv_folder_path, schema=schema, header=False)

# %%
# Save the DataFrame as a Delta table in the Lakehouse
df.write.format("delta")\
        .mode("append")\
        .save("abfss://Formula1@onelake.dfs.fabric.microsoft.com/Formula1_lakehouse.Lakehouse/Tables/bronze_races")
# Out:
# StatementMeta(, 95ce693a-80fc-4232-bb23-f26d0cd3b01b, 6, Finished, Available, Finished)
